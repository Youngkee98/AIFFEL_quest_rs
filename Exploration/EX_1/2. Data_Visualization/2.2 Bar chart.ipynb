# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# 그래프 데이터 
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# %%
# 축 그리기
fig = plt.figure() #도화지(그래프) 객체 생성
#ax1 = fig.add_subplot(1,1,1) #figure.add_subplot(nrows, ncols, index) : nrows행, ncols열로 나눈 서브플롯 중 index에 해당하는 서브플롯을 생성
ax1 = fig.add_subplot(2,2,1) #2행 2열로 나눈 서브플롯 중 첫번째 서브플롯
ax2 = fig.add_subplot(2,2,2) #2행 2열로 나눈 서브플롯 중 두번째 서브플롯
ax3 = fig.add_subplot(2,2,4) #2행 2열로 나눈 서브플롯 중 세번째 서브플롯

# %%
fig2 = plt.figure() # 도화지(그래프) 객체 생성
ax1 = fig2.add_subplot(2,3,1) # 2행 3열로 나눈 서브플롯 중 첫번째 서브플롯
ax2 = fig2.add_subplot(2,3,4) # 2행 3열로 나눈 서브플롯 중 두번째 서브플롯
ax3 = fig2.add_subplot(2,3,5) # 2행 3열로 나눈 서브플롯 중 세번째 서브플롯
ax4 = fig2.add_subplot(2,3,6) # 2행 3열로 나눈 서브플롯 중 네번째 서브플롯

# %%
# 그래프 데이터 
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# 축 그리기
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# 그래프 그리기
ax1.bar(subject,points)

# 라벨, 타이틀 달기
plt.xlabel('Subject')
plt.ylabel('Score')
plt.title("Yuna's Test Result")
# Out:
# <BarContainer object of 5 artists>
